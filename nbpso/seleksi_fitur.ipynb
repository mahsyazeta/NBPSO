# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.naive_bayes import MultinomialNB, BernoulliNB, GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import issparse

# Load data
df = pd.read_csv('text_preprocessing/final_dataset.csv')

# Convert sentiment labels to binary
def convert_label_sentimen(label_sentimen):
    return 1 if label_sentimen == "positive" else 0

df['label_sentimen'] = df['Sentiment'].apply(convert_label_sentimen)
df.drop(df.columns[[0]], axis=1, inplace=True)

X = df['tweet_tokens_stemmed']
y = df['label_sentimen']

# k-fold cross validation (splitting data)
kfold = StratifiedKFold(n_splits=10, random_state=42, shuffle=True)

class NaiveBayes:
    def __init__(self, model_class):
        self.model_class = model_class
        self.clf = None
    
    def fit(self, X_train, y_train, selected_features):
        self.clf = self.model_class()
        if issparse(X_train):
            X_train = X_train.toarray()
        self.clf.fit(X_train[:, selected_features], y_train)
    
    def predict(self, X_test, selected_features):
        if self.clf is None:
            raise ValueError("Classifier not fitted. Please call 'fit' method first.")
        if issparse(X_test):
            X_test = X_test.toarray()
        return self.clf.predict(X_test[:, selected_features])

def evaluate_features(X_train, y_train, selected_features, classifier):
    clf = classifier
    cv_results = cross_val_score(clf.clf, X_train[:, selected_features], y_train, cv=kfold, scoring='accuracy')
    return cv_results.mean()

def display_selected_features(tfidf_model, selected_features):
    feature_names = np.array(tfidf_model.get_feature_names_out())
    selected_feature_names = feature_names[selected_features]
    print("Selected Features:")
    for feature in selected_feature_names:
        print(feature)
    return selected_feature_names

def pso_feature_selection(X_train, y_train, n_particles, inertia, global_weight, local_weight, model_class, tol=1e-5, patience=10):
    num_samples, num_features = X_train.shape
    bounds = [0, 1]
    
    num_particles = n_particles
    dimensions = num_features
    particles = np.random.rand(num_particles, dimensions)
    velocities = np.random.rand(num_particles, dimensions) * 0.1
    best_positions = particles.copy()
    best_scores = np.zeros(num_particles)

    global_best_position = np.zeros(dimensions)
    global_best_score = 0

    no_improvement_count = 0
    previous_global_best_score = 0

    iteration_results = []

    while no_improvement_count < patience:
        for particle in range(num_particles):
            r1 = np.random.rand(dimensions)
            r2 = np.random.rand(dimensions)
            velocities[particle] = (inertia * velocities[particle] +
                                    global_weight * r1 * (best_positions[particle] - particles[particle]) +
                                    local_weight * r2 * (global_best_position - particles[particle]))

            particles[particle] += velocities[particle]
            particles[particle] = np.clip(particles[particle], bounds[0], bounds[1])

            selected_features = particles[particle] > 0.5
            nb = NaiveBayes(model_class)
            nb.fit(X_train, y_train, selected_features)
            accuracy = evaluate_features(X_train, y_train, selected_features, nb)

            if accuracy > best_scores[particle]:
                best_scores[particle] = accuracy
                best_positions[particle] = particles[particle].copy()

            if accuracy > global_best_score:
                global_best_score = accuracy
                global_best_position = particles[particle].copy()

        iteration_results.append((global_best_score, global_best_position.copy()))

        if abs(global_best_score - previous_global_best_score) < tol:
            no_improvement_count += 1
        else:
            no_improvement_count = 0
        
        previous_global_best_score = global_best_score

    return global_best_position > 0.5, iteration_results

# Define parameters for PSO optimization
n_particles = 20
inertia = 0.8
global_weight = 1
local_weight = 0.9

results = []

for model_class in [MultinomialNB, BernoulliNB, GaussianNB]:
    accuracy_scoresTest = []
    accuracy_scoresTrain = []
    precision_scoresTest = []
    precision_scoresTrain = []
    recall_scoresTest = []
    recall_scoresTrain = []

    for train_idx, test_idx in kfold.split(X, y):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        tfidf_model = TfidfVectorizer(smooth_idf=False)
        X_train_tfidf = tfidf_model.fit_transform(X_train)
        X_test_tfidf = tfidf_model.transform(X_test)

        X_train_dense = X_train_tfidf.toarray()
        selected_features, iteration_results = pso_feature_selection(X_train_dense, y_train, n_particles, inertia, global_weight, local_weight, model_class)

        if not np.any(selected_features):
            selected_features[0] = True

        nb = NaiveBayes(model_class)
        nb.fit(X_train_tfidf, y_train, selected_features)

        y_predTest = nb.predict(X_test_tfidf.toarray(), selected_features)

        accuracy_scoresTest.append(accuracy_score(y_test, y_predTest))
        precision_scoresTest.append(precision_score(y_test, y_predTest))
        recall_scoresTest.append(recall_score(y_test, y_predTest))

    fold_results = {
        "Model": model_class.__name__,
        "Average AccuracyTest": np.mean(accuracy_scoresTest),
        "Average PrecisionTest": np.mean(precision_scoresTest),
        "Average RecallTest": np.mean(recall_scoresTest),
    }

    results.append(fold_results)

    print(f"Results for {model_class.__name__}:")
    selected_feature_names = display_selected_features(tfidf_model, selected_features)
    
    print("PSO Iteration Results:")
    for i, (score, position) in enumerate(iteration_results):
        print(f"Iteration {i+1}: Best Score = {score}")

results_df = pd.DataFrame(results)

print(results_df.to_string(index=False))
# Out:
# Results for MultinomialNB:
# Selected Features:
# abang
# abas
# abi
# abis
# abraham
# acara
# acung
# adem
# adil
# adu
# agung
# ahoax
# ahok
# ajah
# ajar
# ajarin
# aksi
# aku
# ala
# alam
# alas
# allah
# alu
# amal
# aman
# amat
# amir
# anak
# anaktapi
# analta
# anastasya
# aneh
# anggota
# angkat
# aniaya
# anis
# anjay
# antem
# apa
# apartemen
# argonya
# argumentasi
# arti
# ary
# asa
# asiknya
# asli
# atur
# ayo
# bagi
# bagus
# bahas
# bahasa
# baik
# bajak
# bakarin
# bambang
# banding
# banget
# bangga
# bangkit
# bangkrut
# bangqomar
# bangsa
# bantai
# bantu
# banyak
# barakallahu
# bareng
# basri
# batas
# batik
# bawa
# bayang
# bayar
# bebas
# becanda
# beda
# bego
# bela
# belah
# belanda
# benar
# benci
# bentak
# bentar
# berani
# berbelitbelit
# berfikir
# bermusyawara
# bersih
# besar
# besok
# biasa
# biaya
# bicara
# bijak
# bijaksana
# bintang
# biru
# bj
# bjh
# bkin
# bnn
# bocor
# bodoh
# bohong
# bom
# bos
# bosan
# botak
# bp
# bpk
# bravo
# btp
# buang
# buk
# buka
# bukti
# bully
# busuk
# buta
# butuh
# cagub
# cak
# campak
# cantik
# cawagub
# cek
# cewe
# cinta
# citra
# club
# comal
# corbuzier
# cowo
# cuman
# curhatanmu
# daerah
# dahlan
# daki
# dalam
# dangdut
# darmawan
# dasar
# deddy
# dedy
# dengar
# dengerin
# deportasi
# desa
# detik
# dewasa
# dialog
# diapaapain
# dicontreng
# didik
# dijalanin
# dikeluarin
# diketawain
# dipikirin
# disabilitas
# diskusi
# ditindes
# diulangulang
# dki
# doa
# domba
# dower
# duga
# duit
# dukung
# duluan
# dunia
# edan
# edukatif
# eep
# ekonomi
# emang
# emosi
# engga
# episode
# eps
# fahri
# fatwa
# favorit
# fitnah
# fon
# foto
# fz
# gadget
# gagal
# gaji
# gampang
# ganda
# ganjar
# ganteng
# gara
# garing
# garingkalah
# gatau
# gaul
# gawat
# gelap
# gelora
# gen
# gerak
# gg
# gigi
# gila
# gimbal
# gin
# gingsul
# gokil
# gosip
# gua
# gue
# gunung
# guru
# gusdur
# gymnastiar
# hab
# habibie
# hadap
# haram
# haru
# haruka
# hati
# hbs
# hebat
# hendak
# hendropriyono
# hewan
# hibur
# hina
# hindar
# hitam
# hitamputih
# hitamputihtrans
# hormat
# hukum
# ibadah
# iblis
# idola
# ikhlas
# ikut
# ilc
# ilmu
# imajinasi
# imbang
# india
# indobesia
# indonesa
# indonesia
# informasi
# inspirasi
# inspiratif
# integritas
# inti
# isi
# isis
# iskan
# islami
# islamis
# istimewa
# istri
# jabat
# jaga
# jago
# jaim
# jakarta
# jalan
# jaman
# jatuh
# jaya
# jebol
# jeket
# jelas
# jembatan
# jempol
# jenderal
# jendral
# jesika
# jhonson
# jiwa
# job
# jokowi
# jual
# juara
# jujur
# jupe
# kacamata
# kadang
# kado
# kagum
# kakak
# kaku
# kalem
# kandang
# kangen
# kanker
# kapolri
# karakter
# karunia
# karya
# kasi
# kasih
# kataberkuasa
# kau
# kawan
# kaya
# kecewa
# kejurnas
# kejut
# keladi
# kelas
# keluar
# keluarga
# keluh
# kemaren
# kemarin
# kemeja
# ken
# kendala
# keren
# kerja
# keruh
# kes
# kesel
# ketawa
# ketek
# kickandy
# kini
# kisah
# kisruh
# knp
# kompak
# komplit
# korupsi
# koruptor
# kosti
# kpi
# kpk
# kpud
# kualifikasi
# kualitas
# kuasa
# kuat
# kunjung
# kyk
# kyknya
# lagu
# lancar
# langgar
# lari
# lawan
# layak
# lemah
# lempar
# lepas
# lesat
# liar
# live
# lucu
# lulus
# maarif
# malam
# malas
# malu
# mampu
# mana
# manfaat
# manggut
# mantab
# manusia
# manyu
# mari
# martha
# marwah
# masakan
# masalah
# master
# masyarakat
# mata
# matanajwa
# matanajwametrotv
# mayoritas
# mbak
# mbk
# medsos
# melayu
# melek
# melempem
# membiyayai
# menang
# mendung
# menentramkan
# menghimbau
# mentang
# merdeka
# merem
# merkids
# metro
# metromini
# mikemarjinal
# milik
# mimpi
# minoritas
# miris
# misbah
# misi
# miskin
# mitos
# mjkt
# moga
# mongol
# motivasi
# msk
# muak
# muas
# muda
# mui
# muka
# mulut
# muncul
# muqoddas
# musisi
# musnah
# muter
# mutu
# muzadi
# nabi
# naik
# najwa
# nama
# nana
# nang
# narapidana
# narasumber
# nasehat
# nasib
# nasionalisme
# nazarudin
# nelen
# nenek
# neng
# net
# netra
# ngadu
# ngakak
# ngantri
# ngantuk
# ngeliat
# ngeselin
# ngoceh
# nipu
# niscaya
# nkri
# nomor
# nongol
# norwegia
# nurani
# nuriyah
# nyaman
# nyanyi
# nyaring
# nyata
# nyelesaikan
# nyetel
# obrol
# ogah
# omong
# one
# online
# orang
# orangorang
# organisasi
# padat
# paham
# pakar
# pake
# paksa
# palingg
# palsu
# pancasila
# parah
# partai
# patut
# pdhl
# pecah
# peci
# pelosok
# pemuda
# penjara
# penta
# penting
# pepet
# perang
# percaya
# pergi
# perintah
# perkara
# persis
# perut
# petir
# pidana
# pikir
# pilih
# pimpin
# pinter
# pirsa
# pkb
# pojok
# polmart
# posisi
# potensi
# powernya
# preman
# presiden
# prestasi
# pribadi
# program
# provokasi
# pssi
# puasa
# puisi
# pungut
# putar
# putih
# racun
# radikal
# radikalisme
# rafly
# rais
# rakyat
# rampas
# rancang
# rangkul
# rasain
# rasmin
# rating
# rayap
# remaja
# reputasi
# reuni
# rezim
# ri
# rias
# ridwan
# rihanna
# rindu
# rokok
# romantis
# roxana
# ruang
# rugi
# rumania
# rusak
# sabar
# safi
# sahabat
# saji
# sakit
# saksi
# salah
# salihin
# salut
# sampah
# sampe
# sandi
# sanggu
# sangka
# sarjana
# satu
# sawah
# sd
# seasia
# sederhana
# sedih
# segitu
# sehat
# sejuk
# sela
# selaras
# semangat
# sembarang
# sempurna
# senandung
# sendri
# sengaja
# senyum
# sepatu
# sera
# seram
# sesat
# setia
# shanijkt
# shinta
# sial
# siar
# sibuk
# sikap
# sila
# silet
# simpen
# sip
# sistem
# slalu
# slamet
# snmptn
# sobat
# sodok
# soleh
# sombong
# sopan
# spensa
# spot
# ssk
# stop
# stres
# stress
# suara
# subhanallah
# suka
# sukses
# sumbang
# sumpah
# sungguh
# super
# sus
# susah
# syafii
# syaiton
# syukur
# tajam
# talkshow
# tambah
# tampang
# tampil
# tamu
# tanda
# tarik
# taruh
# tato
# tayang
# tebang
# teduh
# teguh
# teladan
# televisi
# telor
# teman
# tembak
# tembus
# temu
# tentram
# terap
# terima
# terimakasih
# terkadang
# tertawa
# terusikkpk
# thn
# tipu
# tokoh
# tolol
# tonton
# top
# topi
# topik
# trans
# trio
# ttp
# tuhan
# tuju
# tuna
# tuntas
# turun
# tv
# tvonenews
# tvshow
# tweeps
# uang
# ubah
# udh
# uji
# ujung
# umpat
# umum
# umur
# unjuk
# unyu
# upaya
# upload
# usaha
# usak
# ustad
# usut
# uts
# vermansah
# video
# vocalgrup
# wahh
# wanita
# webnya
# wella
# wibawa
# wijayanto
# wna
# yaampun
# yadia
# yag
# younglex
# zaitun
# zhonk
# PSO Iteration Results:
# Iteration 1: Best Score = 0.788888888888889
# Iteration 2: Best Score = 0.8166666666666667
# Iteration 3: Best Score = 0.8166666666666667
# Iteration 4: Best Score = 0.8166666666666667
# Iteration 5: Best Score = 0.8166666666666667
# Iteration 6: Best Score = 0.8166666666666667
# Iteration 7: Best Score = 0.8194444444444443
# Iteration 8: Best Score = 0.825
# Iteration 9: Best Score = 0.8305555555555555
# Iteration 10: Best Score = 0.8333333333333334
# Iteration 11: Best Score = 0.8333333333333334
# Iteration 12: Best Score = 0.8416666666666668
# Iteration 13: Best Score = 0.8416666666666668
# Iteration 14: Best Score = 0.8416666666666668
# Iteration 15: Best Score = 0.8416666666666668
# Iteration 16: Best Score = 0.8416666666666668
# Iteration 17: Best Score = 0.8472222222222223
# Iteration 18: Best Score = 0.8472222222222223
# Iteration 19: Best Score = 0.8472222222222223
# Iteration 20: Best Score = 0.8472222222222223
# Iteration 21: Best Score = 0.8472222222222223
# Iteration 22: Best Score = 0.8472222222222223
# Iteration 23: Best Score = 0.8472222222222223
# Iteration 24: Best Score = 0.8472222222222223
# Iteration 25: Best Score = 0.8472222222222223
# Iteration 26: Best Score = 0.8472222222222223
# Iteration 27: Best Score = 0.8472222222222223
# Results for BernoulliNB:
# Selected Features:
# abang
# abas
# abi
# abis
# abraham
# acara
# adem
# adil
# adu
# agama
# agung
# ahok
# air
# ajang
# ajar
# ajarin
# akal
# akibatya
# aksi
# aku
# ala
# alam
# alas
# allah
# alu
# amal
# amin
# amir
# anak
# anakanak
# anaktapi
# analta
# anarkis
# ancam
# andy
# aneh
# angkat
# angket
# aniaya
# anis
# anjay
# antem
# apa
# apartemen
# argonya
# asa
# asiknya
# asing
# asuh
# atas
# atlet
# ayah
# ayo
# baby
# bacot
# bae
# bagi
# bagus
# bahagia
# bahas
# baik
# bajak
# bakarin
# bang
# bangga
# bangkit
# bangkrut
# bangsa
# bantai
# banten
# banyak
# barakallahu
# bareng
# baru
# basri
# basuki
# baswedan
# batal
# batas
# batik
# bawa
# bawah
# bayang
# bebas
# becanda
# beda
# bela
# belah
# belanda
# beliau
# benci
# bener
# bentak
# bentar
# berani
# berita
# bermusyawara
# bersih
# besar
# besok
# betawi
# biasa
# biaya
# bidang
# bidik
# bintang
# biru
# bj
# bjh
# bkin
# bnn
# bodoh
# bohong
# bom
# bos
# bosan
# bp
# bravo
# btp
# bu
# buang
# buk
# buka
# bully
# buruk
# busuk
# buta
# butuh
# cagub
# cak
# campak
# capek
# cari
# cawagub
# cek
# cerdas
# cerita
# cewe
# chanel
# cinta
# citra
# coba
# comal
# corbuzier
# cowo
# curhatanmu
# daddy
# dahlan
# daki
# dalem
# dangdut
# dapat
# darmawan
# darurat
# dasar
# debat
# deddy
# dedy
# demo
# dengerin
# deportasi
# desa
# dewan
# dewasa
# diajakin
# dialog
# diapaapain
# dicontreng
# didik
# dijalanin
# dikeluarin
# dipikirin
# ditindes
# dki
# doa
# domba
# dower
# dpp
# duga
# duit
# dukung
# edan
# edukatif
# eep
# ekonomi
# ektp
# engga
# episode
# fahri
# fakta
# favorit
# fitnah
# fon
# formal
# gadget
# gagal
# gaji
# gali
# ganjar
# ganteng
# ganti
# garing
# garingkalah
# gaul
# gawat
# gaya
# gelap
# gemilang
# gen
# generasi
# gg
# gila
# gimbal
# gin
# gingsul
# gokil
# gosip
# gua
# gue
# gunung
# guru
# gusdur
# gymnastiar
# habibie
# habieb
# hadap
# hahaah
# hak
# haram
# harap
# harga
# haru
# hasil
# hasim
# hati
# hbs
# hebat
# hendak
# hendropriyono
# henti
# hewan
# hibur
# hidup
# hina
# hindar
# hitamputih
# hitamputihtrans
# hormat
# host
# hukum
# ibadah
# iblis
# idola
# ikat
# ikut
# ilc
# ilmu
# imajinasi
# imbang
# indah
# india
# indonesa
# indonesia
# informasi
# inspirasi
# inspiratif
# integritas
# inti
# isi
# iskan
# islam
# islamis
# isolir
# istimewa
# istri
# jaga
# jaim
# jajah
# jalan
# jaman
# jasa
# jatuh
# jaya
# jebol
# jeket
# jelas
# jembatan
# jempol
# jendral
# jesika
# jhonson
# jiwa
# jk
# job
# jokowi
# jual
# jujur
# jupe
# kacamata
# kacau
# kado
# kakak
# kakek
# kaku
# kalah
# kalem
# kali
# kangen
# kanker
# kapolri
# karni
# karunia
# kasi
# kasih
# kasihan
# kawan
# kebhinekaan
# kecewa
# kejurnas
# kejut
# keladi
# kelas
# keluar
# keluh
# kemaren
# kemarin
# kemeja
# ken
# kendala
# kepala
# keren
# keringat
# kerja
# kerjan
# keruh
# kes
# ketawa
# ketek
# ketua
# kick
# kickandymetrotv
# kilat
# kini
# kisah
# kisruh
# knp
# komitmen
# komplit
# korupsi
# koruptor
# kosti
# kp
# kpi
# kpud
# kualifikasi
# kualitas
# kuat
# kubur
# kuda
# kyk
# kyknya
# lagu
# lapor
# lari
# lawan
# lawyers
# layak
# lelah
# lemah
# lentera
# lepas
# lesat
# lewat
# lia
# lindung
# live
# lucu
# ludah
# lugas
# lupa
# maaf
# macet
# malam
# malang
# males
# malu
# mampu
# mana
# manfaat
# manggut
# mantab
# mantan
# mantik
# manusia
# manyu
# mari
# martha
# marwah
# masalah
# master
# masyarakat
# matanajwa
# mati
# mayoritas
# mbk
# media
# medsos
# melayu
# melempem
# membiyayai
# menang
# mencak
# mendung
# menentramkan
# mentang
# merah
# merdeka
# merem
# merinding
# metro
# metromini
# metrotv
# mikemarjinal
# milik
# mimpi
# minggu
# minoritas
# miris
# misbah
# misi
# miskin
# mitos
# mjkt
# moga
# motivasi
# msk
# muak
# muas
# muda
# mui
# muka
# muqoddas
# musuh
# muter
# mutu
# muzadi
# nabi
# najwa
# nambah
# nana
# nang
# narasumber
# nasehat
# nasib
# nasihat
# nazarudin
# nenek
# neng
# net
# netra
# ngadu
# ngakak
# ngantri
# ngatain
# ngeselin
# ngoceh
# ngomong
# nipu
# niscaya
# nkri
# nomor
# nonton
# norwegia
# nurani
# nuriyah
# nyala
# nyaman
# nyampah
# nyanyi
# nyaring
# nyata
# nyebelin
# nyelesaikan
# nyetel
# oma
# omong
# ompong
# one
# online
# orangorang
# padat
# paham
# pakar
# pake
# paksa
# palingg
# palsu
# panglima
# parah
# partai
# pas
# pasrah
# patut
# pdhl
# pecah
# peluang
# penjara
# perang
# percaya
# pergi
# perintah
# perkara
# petir
# pidana
# pikir
# pilgub
# pilih
# pilkada
# pirsa
# pkb
# pojok
# polisi
# polmart
# poso
# potensi
# powernya
# preman
# presiden
# prestasi
# pribadi
# prof
# program
# pssi
# puasa
# puisi
# puji
# puncak
# putar
# putih
# putra
# racun
# radikal
# rafly
# rais
# rajut
# rakyat
# rame
# rampas
# rancang
# rangkul
# rating
# rekam
# remaja
# reuni
# rezim
# ri
# rias
# ridwan
# rihanna
# rimba
# rindu
# rizieq
# rokok
# romantis
# ronny
# roxana
# ruang
# rugi
# rumah
# rumania
# rusuh
# sabar
# safi
# sahabat
# saji
# sakit
# salah
# salut
# sampah
# sampe
# sandi
# sanggu
# sanggup
# sangka
# sarjana
# satu
# sawah
# sayang
# sd
# seasia
# sederhana
# segitu
# sehat
# sejuk
# sekian
# sekitar
# sela
# selamat
# selaras
# selera
# selesai
# selip
# semangat
# sembarang
# sempurna
# senandung
# sendri
# senyum
# sepakbola
# sepatu
# sera
# seragam
# seram
# serang
# seru
# sesat
# sesuai
# setan
# shanijkt
# shinta
# sial
# siar
# sibuk
# sikap
# sila
# sip
# sistem
# slalu
# slamet
# sm
# snmptn
# sodara
# sodok
# soleh
# sombong
# sopan
# sp
# spensa
# ssk
# stres
# stress
# suami
# suasana
# suka
# sukses
# sulit
# sumbang
# sumpah
# sungguh
# super
# superbodi
# sus
# susah
# syafii
# syukur
# tajam
# taksi
# takut
# talkshow
# tampang
# tamu
# tarik
# tarpin
# taruh
# tatan
# tau
# tayang
# tebang
# teduh
# tegak
# teguh
# teladan
# televisi
# telor
# teman
# tembak
# tembus
# tentram
# terap
# terima
# terimakasih
# teroris
# terusikkpk
# tetangga
# thanks
# thn
# tindak
# tinggal
# titik
# tokoh
# toleransi
# tolol
# tonton
# top
# topi
# topik
# ttp
# tua
# tuduh
# tuna
# tunduk
# tunggu
# tunjuk
# tuntas
# turun
# tv
# tvne
# tvone
# tvonenews
# tvshow
# tweeps
# ubah
# ucap
# udh
# ujung
# ulas
# umat
# umum
# umur
# unjuk
# unyu
# upaya
# urus
# usaha
# usak
# ustad
# ustadz
# usut
# utadz
# uts
# vermansah
# veteran
# video
# wahh
# wanita
# wawas
# wella
# wihh
# wijayanto
# wna
# woidjojayanto
# yaampun
# yadia
# yag
# younglex
# zaitun
# PSO Iteration Results:
# Iteration 1: Best Score = 0.775
# Iteration 2: Best Score = 0.7833333333333334
# Iteration 3: Best Score = 0.7888888888888889
# Iteration 4: Best Score = 0.8
# Iteration 5: Best Score = 0.8
# Iteration 6: Best Score = 0.8027777777777778
# Iteration 7: Best Score = 0.8138888888888889
# Iteration 8: Best Score = 0.8166666666666667
# Iteration 9: Best Score = 0.8166666666666667
# Iteration 10: Best Score = 0.8166666666666667
# Iteration 11: Best Score = 0.8222222222222222
# Iteration 12: Best Score = 0.8222222222222222
# Iteration 13: Best Score = 0.8222222222222222
# Iteration 14: Best Score = 0.8222222222222222
# Iteration 15: Best Score = 0.8222222222222222
# Iteration 16: Best Score = 0.8222222222222222
# Iteration 17: Best Score = 0.8222222222222222
# Iteration 18: Best Score = 0.8222222222222222
# Iteration 19: Best Score = 0.8222222222222222
# Iteration 20: Best Score = 0.8222222222222222
# Iteration 21: Best Score = 0.8222222222222222
# Results for GaussianNB:
# Selected Features:
# abas
# abis
# abraham
# academi
# acara
# acung
# adu
# agama
# agung
# ahoax
# ahok
# air
# ajah
# ajar
# ajarin
# ajha
# ala
# allah
# alu
# amat
# amir
# anakanak
# anaktapi
# anarkis
# anastasya
# aneh
# angkat
# angket
# aniaya
# anies
# anjay
# apa
# argo
# argonya
# ary
# asa
# asing
# asli
# asuh
# ayo
# baby
# bae
# bagus
# bahagia
# baik
# bakarin
# banding
# bang
# banget
# bangga
# bangkit
# bangqomar
# bangsa
# banten
# baru
# basri
# batal
# batas
# batik
# bawah
# bayang
# bayar
# becanda
# belanda
# beli
# beliau
# bener
# bentak
# bentar
# bentuk
# berani
# berbelitbelit
# berfikir
# berita
# bermusyawara
# bersih
# besar
# besok
# betawi
# biasa
# biaya
# bicara
# bidik
# bijak
# bijaksana
# bintang
# biru
# bkin
# bodoh
# bohong
# bosan
# bp
# bravo
# btp
# bu
# buang
# buk
# bulan
# buruk
# busuk
# buta
# butuh
# cagub
# cak
# campak
# cari
# cawagub
# cek
# cepat
# cerdas
# cerita
# cewe
# cinta
# citra
# club
# cocok
# cowo
# cuman
# daddy
# dahlan
# dakwah
# dalam
# darmawan
# dasar
# debat
# deddy
# dedy
# demo
# dengar
# dengerin
# deportasi
# dewan
# dewasa
# diajakin
# diapaapain
# dicontreng
# didik
# dingin
# dipikirin
# diulangulang
# dki
# doa
# domba
# dower
# dpp
# dpr
# duga
# duka
# dukung
# duluan
# dunia
# edan
# edukatif
# eep
# ektp
# emang
# emosi
# engga
# episode
# fahri
# faisal
# farhat
# fatwa
# formal
# foto
# fz
# gali
# gambar
# gampang
# ganda
# ganjar
# ganteng
# ganti
# gara
# garing
# garingkalah
# gawat
# gaya
# gelap
# gelora
# gemilang
# gg
# gimbal
# gin
# gokil
# gua
# gue
# gunung
# guru
# hab
# habibie
# habieb
# hadap
# hadiah
# hahaah
# hahahaha
# hak
# haram
# harap
# haru
# hasim
# hati
# hendropriyono
# henti
# hina
# hitam
# hitamputih
# hormat
# host
# hujat
# hukum
# iblis
# ikat
# ikhlas
# ilc
# imajinasi
# imbang
# indah
# indobesia
# indonesa
# indonesia
# informasi
# insaallah
# inspiratif
# isi
# iskan
# islam
# islamis
# istimewa
# istri
# jabat
# jago
# jaim
# jajah
# jakarta
# jaman
# jarot
# jateng
# jaya
# jebol
# jelas
# jelek
# jesika
# jiwa
# jk
# jkt
# jokowi
# jual
# juang
# juara
# jujur
# jupe
# kadang
# kado
# kakak
# kakek
# kaku
# kalah
# kalem
# kali
# kandang
# kangen
# kanker
# karakter
# karni
# karunia
# karya
# kasi
# kasih
# kasihan
# kataberkuasa
# kau
# kawan
# kaya
# kebhinekaan
# kecewa
# keladi
# kelas
# keluar
# ken
# kepala
# keren
# kerjan
# keruh
# kes
# kesel
# ketawa
# ketek
# ketua
# kick
# kickandy
# kickandymetrotv
# kilat
# knp
# kompak
# komplit
# konvensional
# korban
# koruptor
# kosti
# kp
# kpk
# kpud
# ku
# kualifikasi
# kualitas
# kuasa
# kubur
# kucing
# kuda
# kunjung
# kyk
# lagu
# lancar
# langgar
# lari
# lawan
# lawyers
# layak
# lelah
# lemah
# lempar
# lentera
# lepas
# lesat
# lewat
# lia
# liat
# lilin
# lindung
# ludah
# lugas
# lulus
# maaf
# macan
# macet
# maksud
# malam
# malang
# malas
# males
# malu
# mampir
# mana
# manfaat
# manggut
# mantab
# mantan
# mantap
# mari
# mario
# marwah
# masakan
# master
# mata
# matanajwa
# matanajwametrotv
# mati
# mayoritas
# mbah
# mbak
# media
# melayu
# melek
# membiyayai
# mencak
# mendung
# mentang
# merdeka
# merem
# merkids
# metromini
# metrotv
# mikemarjinal
# mimin
# mimpi
# miris
# misbah
# misi
# miskin
# mitos
# mjkt
# moga
# mongol
# motivasi
# msk
# muak
# muas
# muda
# mui
# muka
# muqoddas
# musnah
# muter
# mutu
# muzadi
# nabi
# nama
# nambah
# nana
# nang
# narapidana
# narasumber
# nasehat
# nasib
# nazarudin
# negara
# nenek
# neng
# net
# netra
# ngadu
# ngakak
# ngantri
# ngantuk
# ngatain
# ngeselin
# ngoceh
# ngomong
# nilai
# nipu
# niscaya
# nkri
# nomor
# nonton
# norwegia
# nurani
# nyaman
# nyampah
# nyanyi
# nyaring
# nyata
# nyebelin
# nyetel
# obrol
# oke
# oma
# omong
# ompong
# online
# orang
# orangorang
# organisasi
# padat
# pagi
# paham
# paksa
# palsu
# pancasila
# panglima
# partai
# pas
# pasrah
# patut
# pdhl
# pegang
# pelosok
# peluang
# pemuda
# penta
# penting
# pepet
# perang
# percaya
# pergi
# perintah
# perjuagan
# perkara
# persis
# perut
# petinggi
# petir
# pilgub
# pilih
# pimpin
# pirsa
# pkb
# pojok
# pokok
# polmart
# poso
# potensi
# powernya
# preman
# presiden
# prof
# program
# provokasi
# pssi
# puasa
# puji
# pulang
# puncak
# pungut
# putar
# putra
# racun
# radikal
# radikalisme
# rafly
# rakyat
# rame
# rampas
# rancang
# rangkul
# rating
# rayap
# rekam
# remaja
# reputasi
# ri
# rias
# ribet
# ridwan
# rihanna
# rimba
# rindu
# rizieq
# rokok
# romantis
# roxana
# rugi
# rumania
# rusak
# rusuh
# sabar
# safi
# sahabat
# sakit
# salah
# salihin
# salut
# sampah
# sampe
# sanggu
# sarjana
# sawah
# sayang
# seasia
# sederhana
# sedih
# segitu
# sehat
# sekian
# sekitar
# selamat
# selaras
# selera
# selesai
# sembarang
# sendri
# sengaja
# senyum
# sepatu
# seragam
# seram
# serang
# serap
# sering
# sesuai
# setan
# setia
# shanijkt
# shinta
# sia
# sial
# siar
# sikap
# silaturahmi
# simpan
# simpen
# skor
# slalu
# sm
# sodok
# sombong
# sopan
# spot
# ssk
# stop
# stres
# suami
# suara
# suasana
# subhanallah
# suka
# sukses
# sulit
# sumbang
# sungguh
# surga
# syafii
# tai
# taksi
# talkshow
# tambah
# tampang
# tamu
# tanda
# tarik
# tatan
# tato
# tayang
# tebang
# tegak
# tegas
# teladan
# televisi
# telor
# teman
# tembak
# tembus
# terang
# terap
# terima
# terimakasih
# terkadang
# teroris
# tetangga
# titik
# tokoh
# toleransi
# tolol
# tonton
# top
# topi
# trans
# trio
# ttp
# tua
# tuduh
# tuhan
# tuju
# tuna
# tunduk
# tunggu
# tunjuk
# tuntas
# tv
# tvone
# tweeps
# uang
# ubah
# ucap
# udh
# uji
# ujung
# ulas
# umum
# umur
# undang
# unjuk
# unyu
# upaya
# upload
# usak
# ustad
# ustadz
# usut
# uts
# vermansah
# vocalgrup
# wahh
# wanita
# wawas
# whatsapp
# wibawa
# wijayanto
# wna
# woidjojayanto
# yaampun
# yag
# younglex
# PSO Iteration Results:
# Iteration 1: Best Score = 0.7277777777777777
# Iteration 2: Best Score = 0.7361111111111112
# Iteration 3: Best Score = 0.7722222222222221
# Iteration 4: Best Score = 0.7722222222222221
# Iteration 5: Best Score = 0.7722222222222221
# Iteration 6: Best Score = 0.7722222222222223
# Iteration 7: Best Score = 0.7777777777777777
# Iteration 8: Best Score = 0.7861111111111111
# Iteration 9: Best Score = 0.7861111111111111
# Iteration 10: Best Score = 0.7861111111111111
# Iteration 11: Best Score = 0.7861111111111111
# Iteration 12: Best Score = 0.7861111111111111
# Iteration 13: Best Score = 0.788888888888889
# Iteration 14: Best Score = 0.788888888888889
# Iteration 15: Best Score = 0.7944444444444445
# Iteration 16: Best Score = 0.7972222222222223
# Iteration 17: Best Score = 0.7972222222222223
# Iteration 18: Best Score = 0.7972222222222223
# Iteration 19: Best Score = 0.7972222222222223
# Iteration 20: Best Score = 0.8
# Iteration 21: Best Score = 0.8
# Iteration 22: Best Score = 0.8
# Iteration 23: Best Score = 0.8
# Iteration 24: Best Score = 0.8
# Iteration 25: Best Score = 0.8
# Iteration 26: Best Score = 0.8
# Iteration 27: Best Score = 0.8
# Iteration 28: Best Score = 0.8
# Iteration 29: Best Score = 0.8
# Iteration 30: Best Score = 0.8
#         Model  Average AccuracyTest  Average PrecisionTest  Average RecallTest
# MultinomialNB                0.8000               0.777937               0.845
#   BernoulliNB                0.7675               0.751523               0.855
#    GaussianNB                0.7300               0.681263               0.870
